# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# **Pandas** is a software library for Python-based data manipulation and analysis. In particular, it offers data structures and operations for manipulating tables.
#
# The name is derived from the term *panel data*, an econometrics term for datasets that include observations over multiple time periods for the same individuals.
#
# This introudction observes the basic expectations of Tidy Data:
# ![pic1.png](pic1.png)

# %% [markdown]
# ## Let's go!

# %%
# Start by importing Pandas
import pandas as pd

# %% [markdown]
# ## Let's make a table, known in pandas as a **Dataframe**

# %%
# There's lots of ways to make Dataframes. You can specify values for each column in a dictionary:

df = pd.DataFrame({'a' : [1 ,2, 3],
                   'b' : [4, 5, 6],
                   'c' : [7, 8, 9]},
                  index = ['alpha','beta','gamma'])
df
# Out:
#        a  b  c
# alpha  1  4  7
# beta   2  5  8
# gamma  3  6  9

# %%
# You can also specify values for each row as a series of lists... but watch out on how you insert your data!
# Copying and Pasting can lead to mistakes, like this:

df2 = pd.DataFrame([[1 ,2, 3],
                    [4, 5, 6],
                    [7, 8, 9]],
                   index=['alpha','beta','gamma'],
                   columns=['a', 'b', 'c'])

df2
# Out:
#        a  b  c
# alpha  1  2  3
# beta   4  5  6
# gamma  7  8  9

# %%
# These two aren't the same dataframes!
df.eq(df2)
# Out:
#            a      b      c
# alpha   True  False  False
# beta   False   True  False
# gamma  False  False   True

# %%
# Let's try this again:

df3 = pd.DataFrame([[1,4,7],
                    [2,5,8],
                    [3,6,9]],
                   index=['alpha','beta','gamma'],
                   columns=['a', 'b', 'c'])
df3
# Out:
#        a  b  c
# alpha  1  4  7
# beta   2  5  8
# gamma  3  6  9

# %%
df.eq(df3)
# Out:
#           a     b     c
# alpha  True  True  True
# beta   True  True  True
# gamma  True  True  True

# %%
# You could also make a dataframe out of a list of dicts:

df4 = (pd.DataFrame([{'index': 'alpha', 'a': 1, 'b': 4, 'c': 7},
                    {'index': 'beta', 'a': 2, 'b': 5, 'c': 8},
                    {'index': 'gamma', 'a': 3, 'b': 6, 'c': 9}])
       .set_index('index')
       .rename_axis(None)
      )

df4
# Out:
#        a  b  c
# alpha  1  4  7
# beta   2  5  8
# gamma  3  6  9

# %%
# If you need to, you can rename the columns of a DataFrame
df.rename(columns = {'a':'abba', 'b': 'babba', 'c': 'cabba'}, inplace=True)
df
# Out:
#        abba  babba  cabba
# alpha     1      4      7
# beta      2      5      8
# gamma     3      6      9

# %% [markdown]
# ## Dataframes vs. Series

# %%
# A *series* is a one-dimensional labeled array -- that is, either a single column or a single row.
# We can ask Pandas for information about a single series (column) in our dataframe:
df['abba']
# Out:
# alpha    1
# beta     2
# gamma    3
# Name: abba, dtype: int64

# %%
# You can accomplish the same thing thusly:
df.abba
# But beware! If your column labels have spaces or special character, this won't work!
# Out:
# alpha    1
# beta     2
# gamma    3
# Name: abba, dtype: int64

# %%
# It's when you make the series part of *a list of series*, then you've got a dataframe.
# Notice that above, there is only one set of brackets around our 'a' column. When we add another set...
df[['abba']]
# Out:
#        abba
# alpha     1
# beta      2
# gamma     3

# %%
# ...we get a Dataframe. In practical terms, this allows us to make an entirely new dataframes from df by selecting a list of specific columns:
new_df = df[['abba','cabba']]
new_df
# Out:
#        abba  cabba
# alpha     1      7
# beta      2      8
# gamma     3      9

# %%
# Behind these dataframes is the familiar zero-based index methods. We can use this with the *.iloc()* (interger-based index location)
# function to retrieve certain rows by their relative index position.
# Lets get the first row. Single brackets on a single row returns a series...
df.iloc[0]
# Out:
# abba     1
# babba    4
# cabba    7
# Name: alpha, dtype: int64

# %%
# ...And doubles return a dataframe:
df.iloc[[0]]
# Out:
#        abba  babba  cabba
# alpha     1      4      7

# %%
# We can also select multiple rows
df.iloc[[1,2]]
# Out:
#        abba  babba  cabba
# beta      2      5      8
# gamma     3      6      9

# %% [markdown]
# ## Now would be a good time to note the frustrating-at-times inconsistencies in Pandas functions.
#
# As we saw before, single-brackets -- ```df['a']``` or ```df.iloc[0]``` --- returns a series; double brackets -- ```df[['a','c']]``` or ```df.iloc[[1,2]]``` -- returns a dataframe.

# %%
# But if we want a dataframe from a range of rows as a Dataframe, we use... single brackets?
df.iloc[1:3]
# Out:
#        abba  babba  cabba
# beta      2      5      8
# gamma     3      6      9

# %%
# What happens if we use double brackets?
df.iloc[[1:3]]
# Out:
#   File "<ipython-input-17-59e2292c5f9a>", line 2
#     df.iloc[[1:3]]
#               ^
# SyntaxError: invalid syntax

# %%
# And what happens if we pass several rows with single brackets? Our query becomes "find the value at row 1, column 2":
df.iloc[1,2]
# Out:
# 8

# %%
# We can accomplish the same query by using *.loc*, the label-based index location method:
df.loc['beta']['cabba']
# Out:
# 8

# %%
# Depending on which method you use, you can mix and match row or column labels to get single values:
df.loc['beta'][2]
# Out:
# 8

# %%
df.iloc[1]['cabba']
# Out:
# 8

# %%
# You can also use *.loc* to make an entirely new dataframe based on conditional/boolean values
# Let's say we want a dataframe that contains only the rows in our 'a' colum that are greater than or equal to 2
# In addition, we only want the values of columns 'a' and 'c'

df.loc[df['abba'] >= 2, ['abba','cabba']]
# Out:
#        abba  cabba
# beta      2      8
# gamma     3      9

# %%
# Similarly, we can add new columns with math functions
df['dabba'] = df.abba * df.cabba
df
# Out:
#        abba  babba  cabba  dabba
# alpha     1      4      7      7
# beta      2      5      8     16
# gamma     3      6      9     27

# %% [markdown]
# ## Importing and Viewing External Files

# %%
# import excel file
excel = pd.read_excel('inventory-2019-Q1.xlsx')
excel

# %%
# in case no Excel support
excel = pd.read_csv('inventory-2019-Q1.csv')
excel

# %%
# see the first five rows
excel.head()
# Out:
#     Part Number        Manufacturer  Stock Web active  \
# 0         14064             MKS-HPS      1       ebay
# 1         14064             MKS-HPS      1       ebay
# 2      41300420             Veriflo      1       ebay
# 3   21016400025  Applied Materials       1       ebay
# 4   70509090000  Applied Materials       1       ebay
#
#                                         Description      Process Condition  \
# 0   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 1   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 2  Regulator, Veriflo Model # IR400S4PBX4 and Gauge  Other Items       New
# 3                                Power Supply, Opal  Other Items       New
# 4                               COLUMN LINER BACKUP  Other Items       New
#
#                                    Ebay Listing Link
# 0  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 1  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 2  https://www.ebay.com/itm/Veriflo-41300420-Regu...
# 3  https://www.ebay.com/itm/Applied-Materials-210...
# 4  https://www.ebay.com/itm/Applied-Materials-705...

# %%
# see first 3 rows
excel.head(3)
# Out:
#   Part Number Manufacturer  Stock Web active  \
# 0       14064      MKS-HPS      1       ebay
# 1       14064      MKS-HPS      1       ebay
# 2    41300420      Veriflo      1       ebay
#
#                                         Description      Process Condition  \
# 0   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 1   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 2  Regulator, Veriflo Model # IR400S4PBX4 and Gauge  Other Items       New
#
#                                    Ebay Listing Link
# 0  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 1  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 2  https://www.ebay.com/itm/Veriflo-41300420-Regu...

# %%
# see last 5 rows
excel.tail()
# Out:
#     Part Number        Manufacturer  Stock Web active            Description  \
# 175  0020-23494  Applied Materials       1       ebay  Honey Comb Collimator
# 176  0020-24386  Appiled Materials      18       ebay          Cover, 150 mm
# 177  0020-24387  Applied Materials       1       ebay       Pedestal, 150 MM
# 178  0020-25071   Applied Materials      1       ebay             Clamp Ring
# 179  0020-25257  Applied Materials       1       ebay          Insulator Qtz
#
#     Process Condition                                  Ebay Listing Link
# 175     PVD       New  https://www.ebay.com/itm/Applied-Materials-002...
# 176     PVD       New  https://www.ebay.com/itm/Applied-Materials-002...
# 177     PVD       New  https://www.ebay.com/itm/Applied-Materials-002...
# 178     PVD       New                                                NaN
# 179     PVD       New                                                NaN

# %%
# Choose an index column
excel.set_index('Part Number').head()
# Out:
#                     Manufacturer  Stock Web active  \
# Part Number
# 14064                    MKS-HPS      1       ebay
# 14064                    MKS-HPS      1       ebay
# 41300420                 Veriflo      1       ebay
# 21016400025   Applied Materials       1       ebay
#  70509090000  Applied Materials       1       ebay
#
#                                                    Description      Process  \
# Part Number
# 14064          MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items
# 14064          MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items
# 41300420      Regulator, Veriflo Model # IR400S4PBX4 and Gauge  Other Items
# 21016400025                                 Power Supply, Opal  Other Items
#  70509090000                               COLUMN LINER BACKUP  Other Items
#
#              Condition                                  Ebay Listing Link
# Part Number
# 14064              New  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 14064              New  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 41300420           New  https://www.ebay.com/itm/Veriflo-41300420-Regu...
# 21016400025        New  https://www.ebay.com/itm/Applied-Materials-210...
#  70509090000       New  https://www.ebay.com/itm/Applied-Materials-705...

# %%
# Reset the index
excel.reset_index(drop=True).head()
# Out:
#     Part Number        Manufacturer  Stock Web active  \
# 0         14064             MKS-HPS      1       ebay
# 1         14064             MKS-HPS      1       ebay
# 2      41300420             Veriflo      1       ebay
# 3   21016400025  Applied Materials       1       ebay
# 4   70509090000  Applied Materials       1       ebay
#
#                                         Description      Process Condition  \
# 0   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 1   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 2  Regulator, Veriflo Model # IR400S4PBX4 and Gauge  Other Items       New
# 3                                Power Supply, Opal  Other Items       New
# 4                               COLUMN LINER BACKUP  Other Items       New
#
#                                    Ebay Listing Link
# 0  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 1  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 2  https://www.ebay.com/itm/Veriflo-41300420-Regu...
# 3  https://www.ebay.com/itm/Applied-Materials-210...
# 4  https://www.ebay.com/itm/Applied-Materials-705...

# %% [markdown]
# ## Analyzing Data

# %%
# get number of rows
len(excel)
# Out:
# 180

# %%
# Basic descriptive statistics for each (numeric) column
excel.describe()
# Out:
#              Stock
# count   180.000000
# mean     31.927778
# std     393.992996
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max    5287.000000

# %%
# Sort the index?
excel.sort_index()
# Out:
#       Part Number        Manufacturer  Stock Web active  \
# 0           14064             MKS-HPS      1       ebay
# 1           14064             MKS-HPS      1       ebay
# 2        41300420             Veriflo      1       ebay
# 3     21016400025  Applied Materials       1       ebay
# 4     70509090000  Applied Materials       1       ebay
# 5      0010-00212  Applied Materials       1       ebay
# 6     0010-00212W  Appiled Materials       2       ebay
# 7      0010-00298  Appiled Materials       1       ebay
# 8      0010-00309  Applied Materials       1       ebay
# 9     0010-00339W  Applied Materials     110       ebay
# 10     0010-00388   Applied Materials      1       ebay
# 11     0010-00510  Applied Materials       1       ebay
# 12     0010-00510  Applied Materials       1       ebay
# 13     0010-00561  Applied Materials       1       ebay
# 14     0010-00706  Applied Materials       1       ebay
# 15     0010-00724   Applied Materials      1       ebay
# 16     0010-00744  Applied Materials       1       ebay
# 17     0010-00750   Applied Materials      1       ebay
# 18     0010-00764  Applied Materials       3       ebay
# 19     0010-00793  Applied Materials      10       ebay
# 20     0010-01098  Applied Materials       1       ebay
# 21     0010-01322   Applied Materials      1       ebay
# 22     0010-02419  Applied Materials       1       ebay
# 23     0010-02991  Applied Materials       1       ebay
# 24     0010-04542  Applied Materials       1       ebay
# 25     0010-09019  Applied Materials       1       ebay
# 26     0010-09021  Applied Materials       1       ebay
# 27     0010-09052  Applied Materials       3       ebay
# 28     0010-09053  Applied Materials       3       ebay
# 29     0010-09092   Applied Materials      1       ebay
# ..            ...                 ...    ...        ...
# 150    0020-10202  Applied Materials       2       ebay
# 151    0020-10204  Applied Materials       3       ebay
# 152    0020-19001  Applied Materials       2       ebay
# 153    0020-19707  Applied Materials       1       ebay
# 154    0020-20323  Applied Materials       1       ebay
# 155    0020-20430  Applied Materials       3       ebay
# 156    0020-20579   Applied Materials      1       ebay
# 157    0020-20580  Applied Materials       1       ebay
# 158    0020-20586   Applied Materials      1       ebay
# 159    0020-20654  Applied Materials       1       ebay
# 160    0020-20862  Applied Materials       1       ebay
# 161    0020-20986  Applied Materials       5       ebay
# 162    0020-21704  Applied Materials       1       ebay
# 163    0020-21748  Applied Materials       1       ebay
# 164    0020-21754  Applied Materials       2       ebay
# 165    0020-21754  Applied Materials       1       ebay
# 166    0020-21755  Applied Materials       2       ebay
# 167    0020-22196  Applied Materials       3       ebay
# 168    0020-22476  Applied Materials       1       ebay
# 169    0020-23065  Applied Materials       3       ebay
# 170    0020-23075   Applied Materials      1       ebay
# 171    0020-23180  Applied Materials       1       ebay
# 172    0020-23354  Applied Materials       1       ebay
# 173    0020-23355  Applied Materials       1       ebay
# 174    0020-23355  Applied Materials      16       ebay
# 175    0020-23494  Applied Materials       1       ebay
# 176    0020-24386  Appiled Materials      18       ebay
# 177    0020-24387  Applied Materials       1       ebay
# 178    0020-25071   Applied Materials      1       ebay
# 179    0020-25257  Applied Materials       1       ebay
#
#                                           Description      Process Condition  \
# 0     MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 1     MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 2    Regulator, Veriflo Model # IR400S4PBX4 and Gauge  Other Items       New
# 3                                  Power Supply, Opal  Other Items       New
# 4                                 COLUMN LINER BACKUP  Other Items       New
# 5                                          Robot Assy         8300      Used
# 6                  Robot, Assy.   REFURBISHED BY AMAT         8300      Used
# 7                                RF Match, Assy. 8300         8300      Used
# 8                                          Gate Valve         8300      Used
# 9                        Pedestal, Assy. 150 MM Oxide         8300       New
# 10                                           Pedestal         8300       New
# 11                                     Bearing, Assy.         Etch      Used
# 12                                 Bearing, Assy.             Etch      Used
# 13                                  Emission Detector         8300      Used
# 14                     Clamp Ring, Vespal XTAL 150 mm         Etch       New
# 15                                Heat Exchanger, ITC  Other Items      New
# 16                      HE Pressure Controller, Assy.         Etch      Used
# 17                              Bolt Down Cover Assy.         Etch      Used
# 18                                Blade, Assy. 150 MM         8300      New
# 19                                       Wiper, Assy.  Other Items      New
# 20          Refelector, Assy. Cassette Handler 200 MM  Other Items      New
# 21                  Slit Door, SHO Corroson Resistant         Etch      New
# 22                       Clamp Lid, Assy. Emax Kalrez         Etch      New
# 23                             Susceptor, 150 MM WCVD          CVD      New
# 24                        Heater, Assy. 200 MM FC WXZ          CVD      Used
# 25                         Throttle Valve, Assy. Etch         Etch       New
# 26                              I/O Slit Valve, Assy.         5000       New
# 27                                 Tray, Assy. 150 MM         5000      Used
# 28                                Tray, Assy.  200 MM         5000      Used
# 29                                    Ozonator, Assy.         5000       New
# ..                                                ...          ...       ...
# 150                                Door, Chamber Slit         5000       New
# 151                           Susceptor, Plate 200 MM          CVD       New
# 152                           Spacer, Slit Valve  SHO      Centura       New
# 153                                   Deposition Ring  Other Items      Used
# 154                                         Chuck, 8"  Other Items       New
# 155                                   Columator, 8"            PVD      Used
# 156                             Extention Arm DC Bias          PVD       New
# 157                                      Post DC Bias          PVD       New
# 158                             Insert, Preclean Mod.          PVD       New
# 159                          Collimator, PVD Degas             PVD      Used
# 160                          PLATE 6" CCD VACUUM SEAL          PVD       New
# 161                                  Shield, Pedestal          PVD       New
# 162                          Chuck, Orientor 125 MM            PVD       New
# 163                            Hoop, 5" & 6" Preclean          PVD       New
# 164                              Pocket Plate, 150 MM          PVD       New
# 165                              Pocket Plate, 150 mm          PVD       New
# 166                                Clamp Ring, 150 MM          PVD       New
# 167                                      Pedestal, 8"          PVD       New
# 168                             Susceptor, 125 MM MAC          PVD       New
# 169                         Pedestal, 150 MM TIN 101%          PVD       New
# 170                                     Shield, Upper          PVD       New
# 171                         PEDESTAL, AL, 6" 101% TIW          PVD       New
# 172                                 Insulator, Quartz          PVD       New
# 173                                    PC II PEDESTAL          PVD       New
# 174                                    PC II PEDESTAL          PVD       New
# 175                             Honey Comb Collimator          PVD       New
# 176                                     Cover, 150 mm          PVD       New
# 177                                  Pedestal, 150 MM          PVD       New
# 178                                        Clamp Ring          PVD       New
# 179                                     Insulator Qtz          PVD       New
#
#                                      Ebay Listing Link
# 0    https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 1    https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 2    https://www.ebay.com/itm/Veriflo-41300420-Regu...
# 3    https://www.ebay.com/itm/Applied-Materials-210...
# 4    https://www.ebay.com/itm/Applied-Materials-705...
# 5    https://www.ebay.com/itm/Applied-Materials-001...
# 6    https://www.ebay.com/itm/Applied-Materials-001...
# 7                                                  NaN
# 8    https://www.ebay.com/itm/Applied-Materials-001...
# 9                                                  NaN
# 10                                                 NaN
# 11   https://www.ebay.com/itm/Applied-Materials-001...
# 12   https://www.ebay.com/itm/Applied-Materials-001...
# 13                                                 NaN
# 14   https://www.ebay.com/itm/Applied-Materials-001...
# 15   https://www.ebay.com/itm/Applied-Materials-001...
# 16   https://www.ebay.com/itm/Applied-Materials-001...
# 17                                                 NaN
# 18   https://www.ebay.com/itm/Applied-Materials-001...
# 19   https://www.ebay.com/itm/Applied-Materials-001...
# 20   https://www.ebay.com/itm/Applied-Materials-001...
# 21                                                 NaN
# 22   https://www.ebay.com/itm/Applied-Materials-001...
# 23   https://www.ebay.com/itm/Applied-Materials-001...
# 24   https://www.ebay.com/itm/Applied-Materials-001...
# 25   https://www.ebay.com/itm/Applied-Materials-001...
# 26   https://www.ebay.com/itm/Applied-Materials-001...
# 27   https://www.ebay.com/itm/Applied-Materials-001...
# 28   https://www.ebay.com/itm/Applied-Materials-001...
# 29   https://www.ebay.com/itm/Applied-Materials-001...
# ..                                                 ...
# 150  https://www.ebay.com/itm/Applied-Materials-002...
# 151  https://www.ebay.com/itm/Applied-Materials-002...
# 152  https://www.ebay.com/itm/Applied-Materials-002...
# 153  https://www.ebay.com/itm/Applied-Materials-002...
# 154  https://www.ebay.com/itm/Applied-Materials-002...
# 155  https://www.ebay.com/itm/Applied-Materials-002...
# 156                                                NaN
# 157                                                NaN
# 158                                                NaN
# 159  https://www.ebay.com/itm/Applied-Materials-002...
# 160  https://www.ebay.com/itm/Applied-Materials-002...
# 161  https://www.ebay.com/itm/Applied-Materials-002...
# 162                                                NaN
# 163  https://www.ebay.com/itm/Applied-Materials-002...
# 164  https://www.ebay.com/itm/Applied-Materials-002...
# 165  https://www.ebay.com/itm/Applied-Materials-002...
# 166  https://www.ebay.com/itm/Applied-Materials-002...
# 167  https://www.ebay.com/itm/Applied-Materials-002...
# 168  https://www.ebay.com/itm/Applied-Materials-002...
# 169  https://www.ebay.com/itm/Applied-Materials-002...
# 170                                                NaN
# 171  https://www.ebay.com/itm/Applied-Materials-002...
# 172  https://www.ebay.com/itm/Applied-Materials-002...
# 173  https://www.ebay.com/itm/Applied-Materials-002...
# 174                                                NaN
# 175  https://www.ebay.com/itm/Applied-Materials-002...
# 176  https://www.ebay.com/itm/Applied-Materials-002...
# 177  https://www.ebay.com/itm/Applied-Materials-002...
# 178                                                NaN
# 179                                                NaN
#
# [180 rows x 8 columns]

# %%
excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 8 columns):
# Part Number          180 non-null object
# Manufacturer         179 non-null object
# Stock                180 non-null int64
# Web active           180 non-null object
# Description          180 non-null object
# Process              180 non-null object
# Condition            180 non-null object
# Ebay Listing Link    139 non-null object
# dtypes: int64(1), object(7)
# memory usage: 11.3+ KB

# %%
# number of unique values in a column
excel['Process'].nunique()
# Out:
# 14

# %%
# list unique values in a column
excel['Process'].unique()
# Out:
# array(['Other Items', 8300, '8300', 'Etch', 'CVD', '5000', 5000, 'ASP',
#        'Endura', 'PVD', 'DPS', "PCB's", 'RTP', 'Centura'], dtype=object)

# %%
# Count number of rows with each unique value of variable
excel['Process'].value_counts()
# Out:
# Etch           42
# PVD            39
# CVD            29
# Other Items    27
# 5000           14
# 8300            9
# 5000            8
# DPS             4
# Endura          2
# ASP             2
# RTP             1
# 8300            1
# Centura         1
# PCB's           1
# Name: Process, dtype: int64

# %% [markdown]
# ## Remediating Data

# %%
# Remove duplicate rows
excel.drop_duplicates().head()
# Out:
#     Part Number        Manufacturer  Stock Web active  \
# 0         14064             MKS-HPS      1       ebay
# 2      41300420             Veriflo      1       ebay
# 3   21016400025  Applied Materials       1       ebay
# 4   70509090000  Applied Materials       1       ebay
# 5    0010-00212  Applied Materials       1       ebay
#
#                                         Description      Process Condition  \
# 0   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 2  Regulator, Veriflo Model # IR400S4PBX4 and Gauge  Other Items       New
# 3                                Power Supply, Opal  Other Items       New
# 4                               COLUMN LINER BACKUP  Other Items       New
# 5                                        Robot Assy         8300      Used
#
#                                    Ebay Listing Link
# 0  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 2  https://www.ebay.com/itm/Veriflo-41300420-Regu...
# 3  https://www.ebay.com/itm/Applied-Materials-210...
# 4  https://www.ebay.com/itm/Applied-Materials-705...
# 5  https://www.ebay.com/itm/Applied-Materials-001...

# %%
len(excel)
# Out:
# 180

# %%
excel.head()
# Out:
#     Part Number        Manufacturer  Stock Web active  \
# 0         14064             MKS-HPS      1       ebay
# 1         14064             MKS-HPS      1       ebay
# 2      41300420             Veriflo      1       ebay
# 3   21016400025  Applied Materials       1       ebay
# 4   70509090000  Applied Materials       1       ebay
#
#                                         Description      Process Condition  \
# 0   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 1   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 2  Regulator, Veriflo Model # IR400S4PBX4 and Gauge  Other Items       New
# 3                                Power Supply, Opal  Other Items       New
# 4                               COLUMN LINER BACKUP  Other Items       New
#
#                                    Ebay Listing Link
# 0  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 1  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 2  https://www.ebay.com/itm/Veriflo-41300420-Regu...
# 3  https://www.ebay.com/itm/Applied-Materials-210...
# 4  https://www.ebay.com/itm/Applied-Materials-705...

# %%
# To make this permanent either use...
# excel = excel.drop_duplicates()
# OR
excel.drop_duplicates(inplace=True)

# %%
excel.head()
# Out:
#     Part Number        Manufacturer  Stock Web active  \
# 0         14064             MKS-HPS      1       ebay
# 2      41300420             Veriflo      1       ebay
# 3   21016400025  Applied Materials       1       ebay
# 4   70509090000  Applied Materials       1       ebay
# 5    0010-00212  Applied Materials       1       ebay
#
#                                         Description      Process Condition  \
# 0   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 2  Regulator, Veriflo Model # IR400S4PBX4 and Gauge  Other Items       New
# 3                                Power Supply, Opal  Other Items       New
# 4                               COLUMN LINER BACKUP  Other Items       New
# 5                                        Robot Assy         8300      Used
#
#                                    Ebay Listing Link
# 0  https://www.ebay.com/itm/MKS-HPS-Pneumatic-Vac...
# 2  https://www.ebay.com/itm/Veriflo-41300420-Regu...
# 3  https://www.ebay.com/itm/Applied-Materials-210...
# 4  https://www.ebay.com/itm/Applied-Materials-705...
# 5  https://www.ebay.com/itm/Applied-Materials-001...

# %%
len(excel)
# Out:
# 179

# %%
# drop unwanted columns
excel.drop(columns=['Ebay Listing Link'], inplace=True)
excel.head()
# Out:
#     Part Number        Manufacturer  Stock Web active  \
# 0         14064             MKS-HPS      1       ebay
# 2      41300420             Veriflo      1       ebay
# 3   21016400025  Applied Materials       1       ebay
# 4   70509090000  Applied Materials       1       ebay
# 5    0010-00212  Applied Materials       1       ebay
#
#                                         Description      Process Condition
# 0   MKS HPS Pneumatic Vacuum Isolation Valve, Angle  Other Items       New
# 2  Regulator, Veriflo Model # IR400S4PBX4 and Gauge  Other Items       New
# 3                                Power Supply, Opal  Other Items       New
# 4                               COLUMN LINER BACKUP  Other Items       New
# 5                                        Robot Assy         8300      Used

# %%
# Look for null (NaN) values
excel[excel.isnull().any(axis=1)]
# Out:
#     Part Number Manufacturer  Stock Web active                   Description  \
# 120  0010-70321          NaN      1       ebay  Slit Valve, Assy. (lot of 4)
#
#     Process Condition
# 120    5000      Used

# %%
# We can remedy this with either...
# excel.dropna(inplace=True)
# OR
excel.fillna('Unknown', inplace=True)

# %%
excel[excel.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Part Number, Manufacturer, Stock, Web active, Description, Process, Condition]
# Index: []

# %% [markdown]
# ## For-Loops with Dataframe Data

# %%
excel.rename(columns = {'Part Number':'Part_Number'}, inplace=True)

# %%
for row in excel.itertuples():
    print('Part Number: {0}, {1} in stock'.format(row.Part_Number, row.Stock))

# %% [markdown]
# ## Exporting Back to a File

# %%
excel.to_csv('cleaned.csv', index=False)
